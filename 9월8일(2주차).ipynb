# %% [markdown]
# # **9/8 (2주차)![27738433597DCB1312.jpg](data:image/jpeg;base64,...)**

# %%
print("안녕!")
# Out:
# 안녕!

# %%
a = "고양이"

# %% [markdown]
# # 변수

# %%
a = 1.1
b = 2
c = a+b

# %%
a = "1.1"
b = "2"
c = a+b
print(c)
# Out:
# 1.12

# %% [markdown]
# # 연산자

# %%
print("내 이름은 %s입니다." %"민우")
# Out:
# 내 이름은 민우입니다.

# %% [markdown]
# # 제어문

# %% [markdown]
# # 리스트, 튜플, 딕셔너리
