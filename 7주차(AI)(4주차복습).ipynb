# %% [markdown]
# 4주차1강 (PPT에 있는 거 다 알고 있기!)

# %%
#타이타닉 데이터 가져오기

import seaborn as sns

d = sns.load_dataset('titanic')
d
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
d.shape

#몇줄 몇칸 있는지 한꺼번에 보여주는 명령어! 괄호 안쓰고 쓴다.
# Out:
# (891, 15)

# %%
d.info()
#데이터에 대한 정보
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
d.describe()

#수치로 된 데이터에 대한 통계값을 보여줌
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
d['survived']

#survived 필드만 조회할 수 있다.
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64

# %%
d['survived'].value_counts()

#데이터의 개수를 찍어준다.
# Out:
# 0    549
# 1    342
# Name: survived, dtype: int64

# %%
d['sex'].value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
d['who'].value_counts()
# Out:
# man      537
# woman    271
# child     83
# Name: who, dtype: int64

# %%
d2 = d[ d['survived'] == 1 ]
d2

#생존자 (1)을 찾아서 다시 d로 묶어주면 생존자의 데이터만 볼 수 있음!
#생존자 데이터를 집어넣은 새로운 변수 d2를 만듬
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
d2['who'].value_counts()

#생존자들 중 남자, 여자, 아이의 수
# Out:
# woman    205
# man       88
# child     49
# Name: who, dtype: int64

# %%
d2['class'].value_counts()

#등급별로 몇명이 생존했는지
# Out:
# First     136
# Third     119
# Second     87
# Name: class, dtype: int64

# %%
d['class'].value_counts()
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64

# %%
d['class'].value_counts(normalize=True, sort=False)
# Out:
# First     0.242424
# Second    0.206510
# Third     0.551066
# Name: class, dtype: float64

# %% [markdown]
# 4주차 2강

# %%
#구글 드라이브를 이용해서 데이터를 업로드하고, 파일에서 드라이브 마운트 버튼 눌렀음

# %%
import pandas as pd           #파일 가져오기 위해서 판다스 불러움!
apt = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/4주/상도동 아파트 실거래가.xlsx') #상도동 아파트 실거래가 경로복사함!
apt
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#     □ 본 서비스에서 제공하는 정보는 법적인 효력이 없으므로 참고용으로만 활용하시기 바랍니다. Unnamed: 1 Unnamed: 2  \
# 0    □ 신고정보가 실시간 변경, 해제되어 제공시점에 따라 공개건수 및 내용이 상이할 수...        NaN        NaN
# 1    □ 본 자료는 계약일 기준입니다. (※ 7월 계약, 8월 신고건 → 7월 거래건으로...        NaN        NaN
# 2    □ 통계자료 활용시에는 수치가 왜곡될 수 있으니 참고자료로만 활용하시기  바라며, ...        NaN        NaN
# 3                                                  NaN        NaN        NaN
# 4    * 국토교통부 실거래가 공개시스템의 궁금하신 점이나 문의사항은 주택거래신고 1588...        NaN        NaN
# ..                                                 ...        ...        ...
# 222                                      서울특별시 동작구 상도동        533       0533
# 223                                      서울특별시 동작구 상도동        533       0533
# ...

# %%
apt = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/4주/상도동 아파트 실거래가.xlsx',header = [16])
#16번부터 읽어달라고 해서 필드이름이 가장 위에 나오게 함! (엑셀에서는 17번째 줄인데, 파이썬은 0부터 시작하니까 16으로!)
apt
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                시군구   번지   본번  부번             단지명   전용면적(㎡)    계약년월  계약일  \
# 0    서울특별시 동작구 상도동  903  903   0     e편한세상상도노빌리티   59.7827  202301    7
# 1    서울특별시 동작구 상도동  903  903   0     e편한세상상도노빌리티   84.9704  202301   11
# 2    서울특별시 동작구 상도동  903  903   0     e편한세상상도노빌리티   84.9704  202301   18
# 3    서울특별시 동작구 상도동  903  903   0     e편한세상상도노빌리티   59.7827  202302    8
# 4    서울특별시 동작구 상도동  903  903   0     e편한세상상도노빌리티   59.7827  202302   24
# ..             ...  ...  ...  ..             ...       ...     ...  ...
# 206  서울특별시 동작구 상도동  533  533   0  힐스테이트 상도 프레스티지   84.9510  202303   12
# 207  서울특별시 동작구 상도동  533  533   0  힐스테이트 상도 프레스티지   84.9510  202303   23
# 208  서울특별시 동작구 상도동  533  533   0  힐스테이트 상도 프레스티지   84.9510  202304    1
# ...

# %%
#행과 열 데이터 삭제하기 (PPT 9쪽)


apt.drop(index = [3],axis=0,inplace=True)
apt
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-815970a744d5> in <cell line: 4>()
#       2
#       3
# ----> 4 apt.drop(index = [3],axis=0,inplace=True)
#       5 apt
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...
