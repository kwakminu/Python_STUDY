# %%
import pandas as pd

df = pd.read_excel('/content/file.xlsx')
df
# Out:
#   name  age  score
# 0  min   20    100
# 1  kim   21     68
# 2  soo   37     80

# %%
df['score']
# Out:
# 0    100
# 1     68
# 2     80
# Name: score, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.plot([10,20,30,40],[45,7,8,80])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(['a','b','c','d'],[45,7,8,80])
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_excel('/content/file.xlsx')
plt.plot(df['name'], df['score'], color = 'red', marker = 'o')
plt.plot(df['name'], df['age'], color = 'pink', marker = '*')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_excel('/content/연도별출생인구.xlsx')
plt.plot(df['연도'], df['출생아수'], color = 'pink', marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

#전국 16개 영화관의 지상층수와 지하층수 그래프
df = pd.read_excel('/content/fulldata_03_13_02_P_영화상영관.xlsx')
plt.plot(df['번호'], df['지상층수'], color = 'orange', marker = '*')
plt.plot(df['번호'], df['지하층수'], color = 'red', marker = 'o')
plt.show()
